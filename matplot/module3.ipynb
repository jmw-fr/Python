# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# %%
x = np.random.randint(low=0, high=20, size=20)
x.sort()
y = np.random.randint(low=0, high=20, size=20)
y.sort()

x = np.append(x, 37)
x = np.append(x, 40)

plt.boxplot([x, y])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x170fc19c5d0>,
#   <matplotlib.lines.Line2D at 0x170fc19ce50>,
#   <matplotlib.lines.Line2D at 0x170fc1a8410>,
#   <matplotlib.lines.Line2D at 0x170fc1a8cd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x170fc19d6d0>,
#   <matplotlib.lines.Line2D at 0x170fc19dfd0>,
#   <matplotlib.lines.Line2D at 0x170fc1a94d0>,
#   <matplotlib.lines.Line2D at 0x170fc1a9d50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x170fc18bc50>,
#   <matplotlib.lines.Line2D at 0x170fc19fb10>],
#  'medians': [<matplotlib.lines.Line2D at 0x170fc19e8d0>,
#   <matplotlib.lines.Line2D at 0x170fc1aa610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x170fc19f110>,
#   <matplotlib.lines.Line2D at 0x170fc162950>],
#  'means': []}

# %%
plt.boxplot([x, y], vert=False, notch=True, showfliers=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x170fc30d9d0>,
#   <matplotlib.lines.Line2D at 0x170fc30e590>,
#   <matplotlib.lines.Line2D at 0x170fc31dd50>,
#   <matplotlib.lines.Line2D at 0x170fc31e690>],
#  'caps': [<matplotlib.lines.Line2D at 0x170fc30f190>,
#   <matplotlib.lines.Line2D at 0x170fc30fad0>,
#   <matplotlib.lines.Line2D at 0x170fc31c610>,
#   <matplotlib.lines.Line2D at 0x170fc31fb50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x170fc30cdd0>,
#   <matplotlib.lines.Line2D at 0x170fc31d210>],
#  'medians': [<matplotlib.lines.Line2D at 0x170fc31c750>,
#   <matplotlib.lines.Line2D at 0x170fc328650>],
#  'fliers': [],
#  'means': []}

# %%
bp = plt.boxplot([x, y], patch_artist=True)

bp['boxes'][0].set(facecolor='lightyellow')
bp['medians'][0].set(linestyle='--', color='blue')
# Out:
# [None, None]

# %%
sample = np.random.random_sample((100, 10))

plt.boxplot(sample)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x170fbc33610>,
#   <matplotlib.lines.Line2D at 0x170fbc33fd0>,
#   <matplotlib.lines.Line2D at 0x170fbc43310>,
#   <matplotlib.lines.Line2D at 0x170fbc43b50>,
#   <matplotlib.lines.Line2D at 0x170fbc53010>,
#   <matplotlib.lines.Line2D at 0x170fbc538d0>,
#   <matplotlib.lines.Line2D at 0x170fbc62c90>,
#   <matplotlib.lines.Line2D at 0x170fbc63410>,
#   <matplotlib.lines.Line2D at 0x170fbc72750>,
#   <matplotlib.lines.Line2D at 0x170fbc72e10>,
#   <matplotlib.lines.Line2D at 0x170fbc81950>,
#   <matplotlib.lines.Line2D at 0x170fbc829d0>,
#   <matplotlib.lines.Line2D at 0x170fbc95d10>,
#   <matplotlib.lines.Line2D at 0x170fbc96450>,
#   <matplotlib.lines.Line2D at 0x170fbca17d0>,
#   <matplotlib.lines.Line2D at 0x170fbca2050>,
#   <matplotlib.lines.Line2D at 0x170fbcb8d90>,
#   <matplotlib.lines.Line2D at 0x170fbcb95d0>,
#   <matplotlib.lines.Line2D at 0x170fbcc4990>,
#   <matplotlib.lines.Line2D at 0x170fbcc5190>],
#  'caps': [<matplotlib.lines.Line2D at 0x170fbc40950>,
#   <matplotlib.lines.Line2D at 0x170fbc41110>,
#   <matplotlib.lines.Line2D at 0x170fbc50390>,
#   <matplotlib.lines.Line2D at 0x170fbc50d10>,
#   <matplotlib.lines.Line2D at 0x170fbc601d0>,
#   <matplotlib.lines.Line2D at 0x170fbc60ad0>,
#   <matplotlib.lines.Line2D at 0x170fbc63d10>,
#   <matplotlib.lines.Line2D at 0x170fbc70550>,
#   <matplotlib.lines.Line2D at 0x170fbc735d0>,
#   <matplotlib.lines.Line2D at 0x170fbc73fd0>,
#   <matplotlib.lines.Line2D at 0x170fbc83250>,
#   <matplotlib.lines.Line2D at 0x170fbc83b10>,
#   <matplotlib.lines.Line2D at 0x170fbc96d50>,
#   <matplotlib.lines.Line2D at 0x170fbc97390>,
#   <matplotlib.lines.Line2D at 0x170fbc610d0>,
#   <matplotlib.lines.Line2D at 0x170fbca2e10>,
#   <matplotlib.lines.Line2D at 0x170fbcb9fd0>,
#   <matplotlib.lines.Line2D at 0x170fbcba850>,
#   <matplotlib.lines.Line2D at 0x170fbcc5a90>,
#   <matplotlib.lines.Line2D at 0x170fbcc62d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x170fbc32d90>,
#   <matplotlib.lines.Line2D at 0x170fbc42bd0>,
#   <matplotlib.lines.Line2D at 0x170fbc52750>,
#   <matplotlib.lines.Line2D at 0x170fbc623d0>,
#   <matplotlib.lines.Line2D at 0x170fbc71ed0>,
#   <matplotlib.lines.Line2D at 0x170fbc81a50>,
#   <matplotlib.lines.Line2D at 0x170fbc95510>,
#   <matplotlib.lines.Line2D at 0x170fbca0f50>,
#   <matplotlib.lines.Line2D at 0x170fbcb8690>,
#   <matplotlib.lines.Line2D at 0x170fbcc4110>],
#  'medians': [<matplotlib.lines.Line2D at 0x170fbc41a90>,
#   <matplotlib.lines.Line2D at 0x170fbc515d0>,
#   <matplotlib.lines.Line2D at 0x170fbc61350>,
#   <matplotlib.lines.Line2D at 0x170fbc70dd0>,
#   <matplotlib.lines.Line2D at 0x170fbc80850>,
#   <matplotlib.lines.Line2D at 0x170fbc94490>,
#   <matplotlib.lines.Line2D at 0x170fbc97e90>,
#   <matplotlib.lines.Line2D at 0x170fbca3590>,
#   <matplotlib.lines.Line2D at 0x170fbcbb050>,
#   <matplotlib.lines.Line2D at 0x170fbcc6ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x170fbc33550>,
#   <matplotlib.lines.Line2D at 0x170fbc33f50>,
#   <matplotlib.lines.Line2D at 0x170fbc41990>,
#   <matplotlib.lines.Line2D at 0x170fbc52d50>,
#   <matplotlib.lines.Line2D at 0x170fbc810d0>,
#   <matplotlib.lines.Line2D at 0x170fbc94c50>,
#   <matplotlib.lines.Line2D at 0x170fbc806d0>,
#   <matplotlib.lines.Line2D at 0x170fbca04d0>,
#   <matplotlib.lines.Line2D at 0x170fbc53850>,
#   <matplotlib.lines.Line2D at 0x170fbcc7410>],
#  'means': []}

# %%
import pandas as pd

exam_data = pd.read_csv('datasets/exams.csv')
exam_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C            some high school  free/reduced
# 1  female        group C                some college  free/reduced
# 2    male        group A                 high school      standard
# 3    male        group B                some college      standard
# 4  female        group C             master's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          69             61             58
# 1               completed          47             65             69
# 2                    none          66             52             53
# 3                    none          88             89             82
# 4                    none          62             82             76

# %%
exam_scores = exam_data[['math score', 'reading score', 'writing score']]
exam_scores.head()
# Out:
#    math score  reading score  writing score
# 0          69             61             58
# 1          47             65             69
# 2          66             52             53
# 3          88             89             82
# 4          62             82             76

# %%
exam_scores.describe()
# Out:
#        math score  reading score  writing score
# count  100.000000     100.000000     100.000000
# mean    67.150000      69.180000      67.780000
# std     12.797865      13.832607      14.874954
# min     36.000000      34.000000      33.000000
# 25%     56.000000      60.000000      57.750000
# 50%     68.000000      69.000000      68.500000
# 75%     76.000000      80.000000      77.250000
# max     95.000000      99.000000     100.000000

# %%
exam_scores_array = np.array(exam_scores)

bp = plt.boxplot(exam_scores_array, patch_artist=True)

colors = ['blue', 'grey', 'lawngreen']

for i in range(len(bp['boxes'])):
    bp['boxes'][i].set(facecolor=colors[i])
    bp['caps'][2*i + 1].set(color=colors[i])

plt.xticks([1, 2, 3], ['Math', 'Reading', 'Writing'])
# Out:
# ([<matplotlib.axis.XTick at 0x170fdb5ed50>,
#   <matplotlib.axis.XTick at 0x170fdb6fbd0>,
#   <matplotlib.axis.XTick at 0x170fc474f10>],
#  [Text(1, 0, 'Math'), Text(2, 0, 'Reading'), Text(3, 0, 'Writing')])

# %%
vp = plt.violinplot(exam_scores_array)
plt.xticks([1, 2, 3], ['Math', 'Reading', 'Writing'])
# Out:
# ([<matplotlib.axis.XTick at 0x170fda69810>,
#   <matplotlib.axis.XTick at 0x170fdd18a50>,
#   <matplotlib.axis.XTick at 0x170fda3d390>],
#  [Text(1, 0, 'Math'), Text(2, 0, 'Reading'), Text(3, 0, 'Writing')])

# %%
vp = plt.violinplot(exam_scores_array, showmedians=True)
plt.xticks([1, 2, 3], ['Math', 'Reading', 'Writing'])
# Out:
# ([<matplotlib.axis.XTick at 0x170fde0b4d0>,
#   <matplotlib.axis.XTick at 0x170fde19490>,
#   <matplotlib.axis.XTick at 0x170fddc52d0>],
#  [Text(1, 0, 'Math'), Text(2, 0, 'Reading'), Text(3, 0, 'Writing')])

# %%
vp = plt.violinplot(exam_scores_array, showmedians=True, vert=False)
plt.yticks([1, 2, 3], ['Math', 'Reading', 'Writing'])
# Out:
# ([<matplotlib.axis.YTick at 0x170fdd80810>,
#   <matplotlib.axis.YTick at 0x170fde55fd0>,
#   <matplotlib.axis.YTick at 0x170fdde06d0>],
#  [Text(0, 1, 'Math'), Text(0, 2, 'Reading'), Text(0, 3, 'Writing')])

# %%
vp
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x170fdebe310>,
#   <matplotlib.collections.PolyCollection at 0x170fdebf450>,
#   <matplotlib.collections.PolyCollection at 0x170fdeccbd0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x170fda31610>,
#  'cmins': <matplotlib.collections.LineCollection at 0x170fdecf210>,
#  'cbars': <matplotlib.collections.LineCollection at 0x170fded0750>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x170fde6d4d0>}

# %%
vp = plt.violinplot(exam_scores_array, showmedians=True, vert=False)
plt.yticks([1, 2, 3], ['Math', 'Reading', 'Writing'])
colors = ['blue', 'grey', 'lawngreen']

for i in range(len(vp['bodies'])):
    vp['bodies'][i].set(facecolor=colors[i])

vp['cmaxes'].set(color='maroon')
vp['cmins'].set(color='black')
vp['cbars'].set(linestyle=':')
vp['cmedians'].set(linewidth=6)

plt.legend(handles = [vp['bodies'][0], vp['bodies'][1]], labels=['Math', 'Reading'], loc='upper left')

# %%
np_data = pd.read_csv('datasets/national_parks.csv')
np_data.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
np_data.describe()
# Out:
#               Year      Badlands   GrandCanyon   BryceCanyon
# count    57.000000  5.700000e+01  5.700000e+01  5.700000e+01
# mean   1989.000000  1.069524e+06  3.412695e+06  8.408708e+05
# std      16.598193  1.574500e+05  1.255127e+06  4.816281e+05
# min    1961.000000  8.333000e+05  1.253000e+06  2.510000e+05
# 25%    1975.000000  9.502420e+05  2.258200e+06  4.715170e+05
# 50%    1989.000000  1.054325e+06  3.859886e+06  8.080450e+05
# 75%    2003.000000  1.188700e+06  4.401522e+06  1.081521e+06
# max    2017.000000  1.518396e+06  6.254238e+06  2.571684e+06

# %%
n, bins, patchs = plt.hist(np_data['GrandCanyon'],
        facecolor = 'cyan',
        edgecolor = 'blue',
        bins=10)

print("n=", n)
print("bins=", bins)
print("patchs", patchs)
# Out:
# n= [ 5.  9. 10.  2.  1.  9. 16.  2.  1.  2.]
# bins= [1253000.  1753123.8 2253247.6 2753371.4 3253495.2 3753619.  4253742.8
#  4753866.6 5253990.4 5754114.2 6254238. ]
# patchs <BarContainer object of 10 artists>

# %%
plt.hist(np_data['GrandCanyon'],
        facecolor = 'cyan',
        edgecolor = 'blue',
        bins=10,
        density=True)
# Out:
# (array([1.75395169e-07, 3.15711304e-07, 3.50790337e-07, 7.01580675e-08,
#         3.50790337e-08, 3.15711304e-07, 5.61264540e-07, 7.01580675e-08,
#         3.50790337e-08, 7.01580675e-08]),
#  array([1253000. , 1753123.8, 2253247.6, 2753371.4, 3253495.2, 3753619. ,
#         4253742.8, 4753866.6, 5253990.4, 5754114.2, 6254238. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np_data['GrandCanyon'],
        facecolor = 'cyan',
        edgecolor = 'blue',
        bins=10,
        cumulative=True)
# Out:
# (array([ 5., 14., 24., 26., 27., 36., 52., 54., 55., 57.]),
#  array([1253000. , 1753123.8, 2253247.6, 2753371.4, 3253495.2, 3753619. ,
#         4253742.8, 4753866.6, 5253990.4, 5754114.2, 6254238. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np_data['GrandCanyon'],
        facecolor = 'cyan',
        edgecolor = 'blue',
        bins=10,
        alpha= 0.3)

plt.hist(np_data['BryceCanyon'],
        facecolor = 'lightyellow',
        edgecolor = 'maroon',
        bins=10,
        alpha=0.3)
# Out:
# (array([17.,  9.,  8., 13.,  6.,  1.,  1.,  0.,  0.,  2.]),
#  array([ 251000. ,  483068.4,  715136.8,  947205.2, 1179273.6, 1411342. ,
#         1643410.4, 1875478.8, 2107547.2, 2339615.6, 2571684. ]),
#  <BarContainer object of 10 artists>)
