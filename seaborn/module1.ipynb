# %%
# %pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from seaborn) (1.24.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\jmw_f\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

print(sns.__version__)
# Out:
# 0.12.2

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 1.5.2

# %%
wine_data = pd.read_csv('datasets/winequality-white.csv', 
                        names=["Fixed Acidity", "Volatile Acidity", "Citric Acid", "Residual Sugar",
                                "Chlorides", "Free Sulfur Dioxide", "Total Sulfur Dioxide", "Density", 
                                "pH", "Sulphates", "Alcohol", "Quality"],
                        skiprows=1,
                        sep=r'\s*;\s*', engine='python')

wine_data.head()
# Out:
#    Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    Free Sulfur Dioxide  Total Sulfur Dioxide  Density    pH  Sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    Alcohol  Quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
wine_data.tail()
# Out:
#       Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       Free Sulfur Dioxide  Total Sulfur Dioxide  Density    pH  Sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       Alcohol  Quality
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6

# %%
wine_data.describe()
# Out:
#        Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          Chlorides  Free Sulfur Dioxide  Total Sulfur Dioxide      Density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    Sulphates      Alcohol      Quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

wine_data = pd.read_csv('datasets/winequality-white.csv', 
                        names=["Fixed Acidity", "Volatile Acidity", "Citric Acid", "Residual Sugar",
                                "Chlorides", "Free Sulfur Dioxide", "Total Sulfur Dioxide", "Density", 
                                "pH", "Sulphates", "Alcohol", "Quality"],
                        skiprows=1,
                        sep=r'\s*;\s*', engine='python')

sns.distplot(wine_data['Alcohol'])
# Out:
# C:\Users\jmw_f\AppData\Local\Temp\ipykernel_24080\884881283.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(wine_data['Alcohol'])
# <AxesSubplot: xlabel='Alcohol', ylabel='Density'>

# %%
#Let us set up the figure so the plot is clearly visible
#The parameters inside the figsize denote the lengths of the box alloted for the plot
f, ax = plt.subplots(figsize=(15,5))

sns.distplot(wine_data['Alcohol'], kde=False, rug=True)
# Out:
# C:\Users\jmw_f\AppData\Local\Temp\ipykernel_24080\731894184.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(wine_data['Alcohol'], kde=False, rug=True)
# <AxesSubplot: xlabel='Alcohol'>

# %%
f,ax=plt.subplots(figsize=(15,5))

sns.rugplot(wine_data['Alcohol'], height=0.5, axis='x')
# Out:
# C:\Users\jmw_f\AppData\Local\Temp\ipykernel_24080\3106480830.py:3: UserWarning:
#
# The `axis` parameter has been deprecated; use the `x` parameter instead.
# Please update your code; this will become an error in seaborn v0.13.0.
#
#   sns.rugplot(wine_data['Alcohol'], height=0.5, axis='x')
# <AxesSubplot: xlabel='Alcohol'>

# %%
f,ax=plt.subplots(figsize=(15,5))

sns.distplot(wine_data['Alcohol'], hist=False, rug=True);
# Out:
# C:\Users\jmw_f\AppData\Local\Temp\ipykernel_24080\3372217138.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(wine_data['Alcohol'], hist=False, rug=True);

# %%
f,ax=plt.subplots(figsize=(15,5))

sns.set(color_codes=True)
sns.kdeplot(wine_data['Alcohol'],fill=True, color="r")
# Out:
# <AxesSubplot: xlabel='Alcohol', ylabel='Density'>

# %%
f,ax=plt.subplots(figsize=(15,5))


sns.kdeplot(wine_data['Alcohol'])
sns.kdeplot(wine_data['Alcohol'], bw=.04, label="bw: 0.04")
sns.kdeplot(wine_data['Alcohol'], bw=.2, label="bw: 0.2")
sns.kdeplot(wine_data['Alcohol'], bw=2, label="bw: 2")
sns.kdeplot(wine_data['Alcohol'], bw=5, label="bw: 5")
# Out:
# C:\Users\jmw_f\AppData\Local\Temp\ipykernel_24080\2046163279.py:5: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.04`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(wine_data['Alcohol'], bw=.04, label="bw: 0.04")
# C:\Users\jmw_f\AppData\Local\Temp\ipykernel_24080\2046163279.py:6: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.2`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(wine_data['Alcohol'], bw=.2, label="bw: 0.2")
# C:\Users\jmw_f\AppData\Local\Temp\ipykernel_24080\2046163279.py:7: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=2`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(wine_data['Alcohol'], bw=2, label="bw: 2")
# C:\Users\jmw_f\AppData\Local\Temp\ipykernel_24080\2046163279.py:8: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(wine_data['Alcohol'], bw=5, label="bw: 5")
# <AxesSubplot: xlabel='Alcohol', ylabel='Density'>

# %%
sns.jointplot(x='Free Sulfur Dioxide', y='Total Sulfur Dioxide', data=wine_data)

# %%
sns.jointplot(
    x='Free Sulfur Dioxide', y='Total Sulfur Dioxide', 
    data=wine_data,
    xlim={0, 100},
    ylim={0,250})

# %%
#Adding a hex type to the plot
with sns.axes_style('white'):
    sns.jointplot(x='Free Sulfur Dioxide', y='Total Sulfur Dioxide', data=wine_data, 
                  kind='hex',color='k',
                  xlim={0,120}, ylim={0,250})

# %%
sns.jointplot(x='Free Sulfur Dioxide', y='Total Sulfur Dioxide', data=wine_data, 
              kind="kde",
              xlim={0,80}, ylim={0,250})

# %%
# The clip parameters clips the plot to the specified limits

sns.kdeplot(
    x=wine_data['Free Sulfur Dioxide'], 
    y=wine_data['Total Sulfur Dioxide'], 
    clip=(0,250))


#Setting limits to the x and y axes
plt.xlim(0,100)
plt.ylim((0,250))
# Out:
# (0.0, 250.0)
